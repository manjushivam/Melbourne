# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")

# %%
df =pd.read_csv('Melbourne_housing_FULL.csv')
#print(df.nunique())
col=['Suburb','Rooms','Type','Method','SellerG','Regionname','Propertycount','Distance','CouncilArea','Bedroom2','Bathroom','Car','Landsize','BuildingArea','Price']
df1=df[col]
df1.dropna(inplace=True)

# %%
df1=pd.get_dummies(df1,dtype=int)
print(df1)
# Out:
#        Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 2          2         4019.0       2.5       2.0       1.0  0.0     156.0
# 4          3         4019.0       2.5       3.0       2.0  0.0     134.0
# 6          4         4019.0       2.5       3.0       1.0  2.0     120.0
# 11         3         4019.0       2.5       4.0       2.0  0.0     245.0
# 14         2         4019.0       2.5       2.0       1.0  2.0     256.0
# ...      ...            ...       ...       ...       ...  ...       ...
# 34847      3         2940.0      25.5       3.0       2.0  2.0     383.0
# 34849      3         2940.0      25.5       3.0       2.0  2.0     404.0
# 34853      2         6543.0       6.3       2.0       2.0  1.0      98.0
# 34854      2         6543.0       6.3       2.0       1.0  2.0     220.0
# 34856      2         6543.0       6.3       2.0       1.0  0.0     250.0
#
#        BuildingArea      Price  Suburb_Abbotsford  ...  \
# ...

# %%
X=df1.drop(columns=['Price'])
Y=df1['Price']
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.30)

# %%
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
print(model.score(X_train,Y_train))
# Out:
# 0.7478756856219445

# %%
print(model.score(X_test,Y_test))  #over fit
# Out:
# -1251515664208.8257

# %% [markdown]
# L1 IMPLEMENTATION

# %%
from sklearn.linear_model import Lasso
model2=Lasso(alpha=25,max_iter=100,tol=0.1) #alpha &max increased -> accuracy decreased
model2.fit(X_train,Y_train)
# Out:
# Lasso(alpha=25, max_iter=100, tol=0.1)

# %%
print(model2.score(X_test,Y_test))
# Out:
# 0.6729275943703661

# %% [markdown]
# L2 IMPLEMENTATION

# %%
from sklearn.linear_model import Ridge
model3=Ridge(alpha=25,max_iter=100,tol=0.1) #alpha &max increased -> accuracy decreased
model3.fit(X_train,Y_train)
# Out:
# Ridge(alpha=25, max_iter=100, tol=0.1)

# %%
print(model3.score(X_test,Y_test))
# Out:
# 0.6784071161620553
